# %% [markdown]
# # Fetching Pypi data
# This notebook fetches every package from the pypi server (~74000 packages!), extracts the setup.py and any file or folder with the word 'requirements' in it.

# %%
import xmlrpclib
import os
# only one api server so we'll use the deutschland mirror for downloading
client = xmlrpclib.ServerProxy('https://pypi.python.org/pypi')
packages = client.list_packages()
# Out:
# ['pycovjson', 'django-devserver', 'sl_pip', 'rio', 'django-supermigrate', 'wanguangqi', 'postageapp', 'pywikilinks', 'flybywire', 'findr', 'pyIBIS', 'dmf-device-ui', 'km3pipe', 'pygccxml', 'beach', 'tornado-xmlrpc', 'djangoshop-stripe', 'trytond_stock_lot', 'randomwordgenerator', 'pygal', 'shawk', 'pgcli', 'uranium', 'cerberus-collections', 'bobot', 'trytond_sale', 'rss_parse', 'pantsbuild.pants.contrib.buildgen', 'matrixmath', 'auto-list-indent', 'web3', 'neurom', 'blosc', 'bam_readgroup_to_json', 'prestans3-tools', 'anycingnesterprint', 'eea.progressbar', 'themis.finals.api.auth', 'PyMata', 'tornadis', 'b3j0f.conf', 'jupyterhub-kubernetes-spawner', 'PepipostAPIV10Lib', 'sge-pygame', 'SDoc', 'Cary_nester', 'rrg', 'pwntools', 'productstatus-client', 'gps3', 'pyosf', 'cosmos', 'bag', 'pandas-profiling', 'eppy', 'aka', 'sqlibrist', 'fio_sale_confirmation_email', 'sitesearcher', 'trytond_nereid_cart_b2c', 'spotifyPlaylistConverter', 'django-extra-fields', 'django-reamaze', 'plumd', 'pyleetx', 'sendgrid', 'simpleDecorators', 'xontrib-avox', 'ldap_playbook', 'convertbng', 'pyoctree', 'sqlalchemy-datatables', 'github-email-explorer', 'fio_waiting_customer_shipment_report', 'cnx-archive', 'getgauge', 'django-yubin', 'youtube_dl', 'python-firm', 'memegen-desktop', 'Density_Sampling', 'sphinxcontrib-vcs', 'Flask-UltraJSON', 'PyGGI', 'pytest-falcon', 'restructuredtext_lint', 'grafana-dashboard-builder', 'eea.pdf', 'invenio-accounts-rest', 'openlibrary-client', 'nlgen', 'themis.finals.checker.app', 'newspider', 'h5netcdf', 'py-jsonapi-sqlalchemy', 'Py-Authorize', 'kdr', 'libvirt-python', 'snmpy', 'kanren', 'pynoc', 'OlymLibrary', 'fio_payment_gateway', 'escea', 'overrides', 'gameclock', 'class', 'pantsbuild.pants.contrib.python.checks', 'nece', 'iso8601utils', 'trytond_stock', 'pkulogin', 'retirejs', 'vunit_hdl', 'listall', 'verata', 'trytond_google_maps', 'ovh_api_cli', 'parse-torrent-name', 'Numscrypt', 'themis.finals.checker.result', 'count_min_sketch', 'ljq_helloWorld', 'django-electron-pdf', 'configparserplus', 'firebase-idtoken', 'django-readonly-field', 'jupyterhub-simplespawner', 'yoyo-migrations', 'exp10it', 'inotify', 'cnx-query-grammar', 'trytond_nereid_catalog_tree', 'ibis', 'spylota', 'SinaL2', 'SAMLSchtron', 'lightstep', 'static_tl', 'mdsplus-alpha', 'mixpanel-api', 'timeoutcontext', 'gunicorn_thrift', 'fio_carrier_pricelist', 'shock', 'fio_sale_channel', 'django-registry', 'django-systemjs', 'raftkit', 'PyRIC', 'jupyterhub-kubespawner', 'amo-validator', 'pyptly', 'hanger51client', 'fanfou', 'iSearch', 'rpi2caster', 'v8bot', 'sapphirehx_nester', 'love', 'pinax-news', 'atomman', 'SaltTesting', 'aiohttp-xmlrpc', 'keepercommander', 'chidg', 'graphql-core', 'jupyterhub-ldapcreateusers', 'docker-pycreds', 'pytorrentz', 'pymatgen', 'bcTesting', 'nester_libo', 'pandas', 'libaudioverse', 'openstax-accounts', 'ucwa', 'trytond_company', 'ingit', 'yarl', 'holidays', 'pywls', 'jsonipy', 'django-g-recaptcha', 'slowjam', 'tickle-me-email', 'activedetect', 'python-instagram-2', 'libmsiecf-python', 'nbxmpp', 'guessit', 'python-smooch', 'Micromigrate', 'fishnet', 'warpdrive', 'myfitnesspal', 'auto_hxp', 'meds', 'mutornadomon', 'pantsbuild.pants.contrib.node', 'slacker', 'skoolkit', 'calmjs.bower', 'physt', 'valueobject', 'vera', 'zun-ui', 'pygraph-cli', 'djangocms-inherit', 'durable_rules', 'brotlipy', 'py-require', 'krpctools', 'amspy', 'django-postgres-fuzzycount', 'yadage', 'Wallace', 'resin-sdk', 'trackmac', 'collective.warmup', 'pantsbuild.pants.contrib.android', 'supermodel', 'Social-Federation', 'curtsies', 'synergy_scheduler', 'aiohipchat', 'saisunkam', 'timeWarpOB', 'nester1001', 'pydcs', 'pycf', 'nester23', 'ezalchemy', 'eth-testrpc', 'pew', 'flarecast-utils', 'pgctl', 'mol2_pack', 'jaraco.translate', 'zict', 'pygments-style-tomorrownightbright', 'vr.imager', 'django-supervisor', 'scriptler', 'srxraylib', 'bombbomb', 'django-orderable', 'Flask-SQLAlchemySession', 'zerorpc', 'polyarchiv', 'pydrda', 'PyNeb', 'nba_data', 'ibmdbpy', ' ...

# %%
import tarfile, re, requests, csv, json
from base64 import b64encode
# from kglib.utils.HelperFunctions import ensure_dir
                
def ensure_dir(f):
    d = os.path.dirname(f)
    if not os.path.exists(d):
        os.makedirs(d)
    
def _save_file(pathname, member, tar_file):
    try:
        content = tar_file.extractfile(member).read()
    except:
        return
    
    outfilename = '{}{}'.format(pathname, os.path.basename(member.name))
    ensure_dir(outfilename)
    with open(outfilename, 'w') as outfile:
        outfile.write(content)
    return
                

def _extract_files(package_file, name):
    try:
        tar_file = tarfile.open(fileobj=package_file)
    except:
        return
    for member in tar_file.getmembers():
        if 'setup.py' in member.name or 'requirements' in member.name:
            _save_file(name, member, tar_file)
        #    content = tar_file.extractfile(member).read()
        #    with open('{}{}'.format(name, os.path.basename(member.name)), 'w') as outfile:
        #        outfile.write(content)
        #elif 'requirements' in member.name:
        #    content = tar_file.extractfile(member).read()
        #    with open('{}{}'.format(name, os.path.basename(member.name)), 'w') as outfile:
        #        outfile.write(content)
                
                
def extract_package_latest(name, client=xmlrpclib.ServerProxy('http://pypi.python.org/pypi')):
    for release in client.package_releases(name):
        outdir = 'packages/{}-{}/'.format(name, release)
        doc = client.release_urls(name, release)
        print doc
        if doc:
            url = None
            for d in doc:
                print d 
                if d['python_version'] == 'source' and d['url'].endswith('gz'):
                    url = d['url']
            if url:
                req = requests.get(url)
                if req.status_code != 200:
                    print "Could not download file %s" % req.status_code
                else:
                    #print(outdir)
                    ensure_dir('{}'.format(outdir))
                    with open('/tmp/temp_tar', 'w') as tar_file:
                        tar_file.write(req.content)
                    with open('/tmp/temp_tar', 'r') as tar_file:
                        return _extract_files(tar_file, name=outdir)

# %%
for i, package in enumerate(packages):
    if i % 100 == 0:
        print('Extracting package {} / {}'.format(i+1, len(packages)))
    #print(package)
    
    extract_package_latest(package, client)
# Out:
# Extracting package 1 / 94191
# [{'has_sig': False, 'upload_time': <DateTime '20130711T00:07:26' at 1069b0ab8>, 'comment_text': '', 'python_version': 'source', 'url': 'https://pypi.python.org/packages/5e/d3/1cec3136c2f208a7529b82b53372da3bf82eb931be5434622c541d08de9d/d-0.2.2.tar.gz', 'md5_digest': 'a174b212b921cf03ca033f823701145b', 'downloads': 3971, 'filename': 'd-0.2.2.tar.gz', 'packagetype': 'sdist', 'path': '5e/d3/1cec3136c2f208a7529b82b53372da3bf82eb931be5434622c541d08de9d/d-0.2.2.tar.gz', 'size': 27780}]
# {'has_sig': False, 'upload_time': <DateTime '20130711T00:07:26' at 1069b0ab8>, 'comment_text': '', 'python_version': 'source', 'url': 'https://pypi.python.org/packages/5e/d3/1cec3136c2f208a7529b82b53372da3bf82eb931be5434622c541d08de9d/d-0.2.2.tar.gz', 'md5_digest': 'a174b212b921cf03ca033f823701145b', 'downloads': 3971, 'filename': 'd-0.2.2.tar.gz', 'packagetype': 'sdist', 'path': '5e/d3/1cec3136c2f208a7529b82b53372da3bf82eb931be5434622c541d08de9d/d-0.2.2.tar.gz', 'size': 27780}
# []
# [{'has_sig': False, 'upload_time': <DateTime '20130529T01:09:34' at 1069d89e0>, 'comment_text': '', 'python_version': 'source', 'url': 'https://pypi.python.org/packages/22/94/2c8ae1f5a1173347404c7d94a7dd822ff059ff6d19f8fa6240ffde1cb956/a-1.0.tar.gz', 'md5_digest': '919d232f6fd0649c525d13f218e06184', 'downloads': 6663, 'filename': 'a-1.0.tar.gz', 'packagetype': 'sdist', 'path': '22/94/2c8ae1f5a1173347404c7d94a7dd822ff059ff6d19f8fa6240ffde1cb956/a-1.0.tar.gz', 'size': 564}]
# {'has_sig': False, 'upload_time': <DateTime '20130529T01:09:34' at 1069d89e0>, 'comment_text': '', 'python_version': 'source', 'url': 'https://pypi.python.org/packages/22/94/2c8ae1f5a1173347404c7d94a7dd822ff059ff6d19f8fa6240ffde1cb956/a-1.0.tar.gz', 'md5_digest': '919d232f6fd0649c525d13f218e06184', 'downloads': 6663, 'filename': 'a-1.0.tar.gz', 'packagetype': 'sdist', 'path': '22/94/2c8ae1f5a1173347404c7d94a7dd822ff059ff6d19f8fa6240ffde1cb956/a-1.0.tar.gz', 'size': 564}
# []
# []
# [{'has_sig': False, 'upload_time': <DateTime '20130711T00:07:26' at 105d618c0>, 'comment_text': '', 'python_version': 'source', 'url': 'https://pypi.python.org/packages/5e/d3/1cec3136c2f208a7529b82b53372da3bf82eb931be5434622c541d08de9d/d-0.2.2.tar.gz', 'md5_digest': 'a174b212b921cf03ca033f823701145b', 'downloads': 3971, 'filename': 'd-0.2.2.tar.gz', 'packagetype': 'sdist', 'path': '5e/d3/1cec3136c2f208a7529b82b53372da3bf82eb931be5434622c541d08de9d/d-0.2.2.tar.gz', 'size': 27780}]
# {'has_sig': False, 'upload_time': <DateTime '20130711T00:07:26' at 105d618c0>, 'comment_text': '', 'python_version': 'source', 'url': 'https://pypi.python.org/packages/5e/d3/1cec3136c2f208a7529b82b53372da3bf82eb931be5434622c541d08de9d/d-0.2.2.tar.gz', 'md5_digest': 'a174b212b921cf03ca033f823701145b', 'downloads': 3971, 'filename': 'd-0.2.2.tar.gz', 'packagetype': 'sdist', 'path': '5e/d3/1cec3136c2f208a7529b82b53372da3bf82eb931be5434622c541d08de9d/d-0.2.2.tar.gz', 'size': 27780}
# [{'has_sig': True, 'upload_time': <DateTime '20130327T04:15:36' at 105d54ef0>, 'comment_text': '', 'python_version': 'source', 'url': 'https://pypi.python.org/packages/79/19/8bdbb33a50c0a76eac690ecad9add56e1de1b08c657ac0faa862b7662be6/e-1.4.5.tar.gz', 'md5_digest': 'b8623702b692bc7a08ca1de5ba37bcc2', 'downloads': 6680, 'filename': 'e-1.4.5.tar.gz', 'packagetype': 'sdist', 'path': '79/19/8bdbb33a50c0a76eac690ecad9add56e1de1b08c657ac0faa862b7662be6/e-1.4.5.tar.gz', 'size': 1800}]
# {'has_sig': True, 'upload_time': <DateTime '20130327T04:15:36' at 105d54ef0>, 'comment_text': '', 'python_version': 'source', 'url': 'https://pypi.python.org/packages/79/19/8bdbb33a50c0a76eac690ecad9add56e1de1b08c657ac0faa862b7662be6/e-1.4.5.tar.gz', 'md5_digest': 'b8623702b692bc7a08ca1de5ba37bcc2', 'downloads': 6680, 'filename': 'e-1.4.5.tar.gz', 'packagetype': 'sdist', 'path': '79/19/8bdbb33a50c0a76eac690ecad9add56e1de1b08c657ac0faa862b7662be6/e-1.4.5.tar.gz', 'size': 1800}
# [{'has_sig': False, 'upload_time': <DateTime '20150105T12:28:42' at 105d56560>, 'comment_text': '', 'python_version': 'source', 'url': 'https://pypi.python.org/packages/44/5b/8c4e53a2e71764bb65ccd9d01158289d5731967e4f3c39c3aaa979a9eada/v-2.1.0.tar.gz', 'md5_digest': '498621b6eabbc360d0d2331ad117847e', 'downloads': 2655, 'filename': 'v-2.1.0.tar.gz', 'packagetype': 'sdist', 'path': '44/5b/8c4e53a2e71764bb65ccd9d01158289d5731967e4f3c39c3aaa979a9eada/v-2.1.0.tar.gz', 'size': 3528}]
# {'has_sig': False, 'upload_time': <DateTime '20150105T12:28:42' at 105d56560>, 'comment_text': '', 'python_version': 'source', 'url': 'https://pypi.python.org/packages/44/5b/8c4e53a2e71764bb65ccd9d01158289d5731967e4f3c39c3aaa979a9eada/v-2.1.0.tar.gz', 'md5_digest': '498621b6eabbc360d0d2331ad117847e', 'downloads': 2655, 'filename': 'v-2.1.0.tar.gz', 'packagetype': 'sdist', 'path': '44/5b/8c4e53a2e71764bb65ccd9d01158289d5731967e4f3c39c3aaa979a9eada/v-2.1.0.tar.gz', 'size': 3528}
# []
# [{'has_sig': True, 'upload_time': <DateTime '20130327T04:15:36' at 105d58bd8>, 'comment_text': '', 'python_version': 'source', 'url': 'https://pypi.python.org/packages/79/19/8bdbb33a50c0a76eac690ecad9add56e1de1b08c657ac0faa862b7662be6/e-1.4.5.tar.gz', 'md5_digest': 'b8623702b692bc7a08ca1de5ba37bcc2', 'downloads': 6680, 'filename': 'e-1.4.5.tar.gz', 'packagetype': 'sdist', 'path': '79/19/8bdbb33a50c0a76eac690ecad9add56e1de1b08c657ac0faa862b7662be6/e-1.4.5.tar.gz', 'size': 1800}]
# {'has_sig': True, 'upload_time': <DateTime '20130327T04:15:36' at 105d58bd8>, 'comment_text': '', 'python_version': 'source', 'url': 'https://pypi.python.org/packages/79/19/8bdbb33a50c0a76eac690ecad9add56e1de1b08c657ac0faa862b7662be6/e-1.4.5.tar.gz', 'md5_digest': 'b8623702b692bc7a08ca1de5ba37bcc2', 'downloads': 6680, 'filename': 'e-1.4.5.tar.gz', 'packagetype': 'sdist', 'path': '79/19/8bdbb33a50c0a76eac690ecad9add56e1de1b08c657ac0faa862b7662be6/e-1.4.5.tar.gz', 'size': 1800}
# []
# [{'has_sig': False, 'upload_time': <DateTime '20150105T12:28:42' at 105d5a248>, 'comment_text': '', 'python_version': 'source', 'url': 'https://pypi.python.org/packages/44/5b/8c4e53a2e71764bb65ccd9d01158289d5731967e4f3c39c3aaa979a9eada/v-2.1.0.tar.gz', 'md5_digest': '498621b6eabbc360d0d2331ad117847e', 'downloads': 2655, 'filename': 'v-2.1.0.tar.gz', 'packagetype': 'sdist', 'path': '44/5b/8c4e53a2e71764bb65ccd9d01158289d5731967e4f3c39c3aaa979a9eada/v-2.1.0.tar.gz', 'size': 3528}]
# {'has_sig': False, 'upload_time': <DateTime '20150105T12:28:42' at 105d5a248>, 'comment_text': '', 'python_version': 'source', 'url': 'https://pypi.python.org/packages/44/5b/8c4e53a2e71764bb65ccd9d01158289d5731967e4f3c39c3aaa979a9eada/v-2.1.0.tar.gz', 'md5_digest': '498621b6eabbc360d0d2331ad117847e', 'downloads': 2655, 'filename': 'v-2.1.0.tar.gz', 'packagetype': 'sdist', 'path': '44/5b/8c4e53a2e71764bb65ccd9d01158289d5731967e4f3c39c3aaa979a9eada/v-2.1.0.tar.gz', 'size': 3528}
# [{'has_sig': True, 'upload_time': <DateTime '20130327T04:15:36' at 105d5b290>, 'comment_text': '', 'python_version': 'source', 'url': 'https://pypi.python.org/packages/79/19/8bdbb33a50c0a76eac690ecad9add56e1de1b08c657ac0faa862b7662be6/e-1.4.5.tar.gz', 'md5_digest': 'b8623702b692bc7a08ca1de5ba37bcc2', 'downloads': 6680, 'filename': 'e-1.4.5.tar.gz', 'packagetype': 'sdist', 'path': '79/19/8bdbb33a50c0a76eac690ecad9add56e1de1b08c657ac0faa862b7662be6/e-1.4.5.tar.gz', 'size': 1800}]
# {'has_sig': True, 'upload_time': <DateTime '20130327T04:15:36' at 105d5b290>, 'comment_text': '', 'python_version': 'source', 'url': 'https://pypi.python.org/packages/79/19/8bdbb33a50c0a76eac690ecad9add56e1de1b08c657ac0faa862b7662be6/e-1.4.5.tar.gz', 'md5_digest': 'b8623702b692bc7a08ca1de5ba37bcc2', 'downloads': 6680, 'filename': 'e-1.4.5.tar.gz', 'packagetype': 'sdist', 'path': '79/19/8bdbb33a50c0a76eac690ecad9add56e1de1b08c657ac0faa862b7662be6/e-1.4.5.tar.gz', 'size': 1800}
# []

# %% [markdown]
# We now have the setup.py and requirements files for every pypi package. I use my own fork of [this repository](https://github.com/landscapeio/requirements-detector) to find the requirements for every package with the following script:
#
# ```bash
# for p in packages/*
# do
#   echo $p
#   detect-requirements $p
#   echo ''
# done
# ```
#
# I will parse the output of this using a different notebook.
